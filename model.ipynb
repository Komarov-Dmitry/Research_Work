# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('job_dataset')
df
# Out:
#                  area          schedule          experience        employment
# 1               Минск  Удаленная работа  От 1 года до 3 лет  Полная занятость  \
# 2              Алматы       Полный день  От 1 года до 3 лет  Полная занятость
# 3              Алматы       Полный день  От 1 года до 3 лет  Полная занятость
# 4               Минск       Полный день           Нет опыта  Полная занятость
# 5     Санкт-Петербург  Удаленная работа           Нет опыта  Полная занятость
# ...               ...               ...                 ...               ...
# 7922            Томск       Полный день           Нет опыта        Стажировка
# 7923             Тула       Полный день           Нет опыта  Полная занятость
# 7924           Москва       Полный день           Нет опыта        Стажировка
# 7926           Москва  Удаленная работа       От 3 до 6 лет  Полная занятость
# 7927           Москва       Полный день           Нет опыта        Стажировка
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4944 entries, 1 to 7927
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   area        4944 non-null   object
#  1   schedule    4944 non-null   object
#  2   experience  4944 non-null   object
#  3   employment  4944 non-null   object
#  4   key_skills  4944 non-null   object
#  5   job         4944 non-null   object
#  6   salary_rub  4944 non-null   int64
# dtypes: int64(1), object(6)
# memory usage: 309.0+ KB

# %%
df.isnull().sum()
# Out:
# area          0
# schedule      0
# experience    0
# employment    0
# key_skills    0
# job           0
# salary_rub    0
# dtype: int64
